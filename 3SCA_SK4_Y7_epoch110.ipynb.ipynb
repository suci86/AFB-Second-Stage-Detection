# %% [markdown]
# # 1.1 Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)

# %% [markdown]
# # 1.2 Installing our dependencies
#
# **Note**: While installing dependencies it will prompt to restart runtime, don't worry just restart it and only run the above **1.1 Mounting google drive** cell.

# %%
#jangan upgrade numpy kalau mau train dataset
#!pip install numpy --upgrade
# !pip install mahotas
# !pip install opencv-contrib-python

# %%
# Download YOLOv7 repository and install requirements
#yg asli cmn dari wongkinyiu
#jangan lupa ganti direktori download paket yolov7ny
# %cd /content/gdrive/MyDrive/37_Y7
#%cd /content
#!git clone https://github.com/WongKinYiu/yolov7.git
# %cd yolov7
# !pip install -r requirements.txt
# !pip install roboflow

# %%
# %pip install scipy
# !pip install findpeaks
# !pip install --upgrade imutils

# %%
# !pip install -U scikit-learn

# %%
# !pip install colorama
import colorama
from colorama import Fore, Back
print(Fore.BLACK + 'BLACK')
print(Fore.BLUE + 'BLUE')
print(Fore.CYAN + 'CYAN')
print(Fore.GREEN + 'GREEN')
print(Fore.LIGHTBLACK_EX + 'LIGHTBLACK_EX')
print(Fore.LIGHTBLUE_EX + 'LIGHTBLUE_EX')
print(Fore.LIGHTCYAN_EX + 'LIGHTCYAN_EX')
print(Fore.LIGHTGREEN_EX + 'LIGHTGREEN_EX')
print(Fore.LIGHTMAGENTA_EX + 'LIGHTMAGENTA_EX')
print(Fore.LIGHTRED_EX + 'LIGHTRED_EX')
print(Fore.LIGHTWHITE_EX + 'LIGHTWHITE_EX')
print(Fore.LIGHTYELLOW_EX + 'LIGHTYELLOW_EX')
print(Fore.MAGENTA + 'MAGENTA')
print(Fore.RED + 'RED')
print(Fore.RESET + 'RESET')
print(Fore.WHITE + 'WHITE')
print(Fore.YELLOW + 'YELLOW')

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

import colorsys
test_color = colorsys.hsv_to_rgb(359, 100, 100)
print(test_color)

# %%
#Print Total AFB
import os
from skimage import data, io
import matplotlib.pyplot as plt
dirCrop='/content/gdrive/MyDrive/Hasil Uji SK4/YOLOv7/TB 1+/exp01A-154'
dir=dirCrop
for path in os.listdir(dirCrop):
        image =io.imread(os.path.join(dir, path))
        plt.figure(figsize=(8, 5))
        plt.subplot(1, 2, 1), plt.title(os.path.basename(path)), plt.imshow(image), plt.axis('off')
print('Total Boxes (Cropped):', len(os.listdir(dirCrop)), 'AFB')

# %% [markdown]
# #Pre-Requirement

# %%
#VGG
from warnings import filterwarnings
import tensorflow
from PIL import Image
import glob
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img, save_img, img_to_array
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam,SGD,RMSprop,Adamax
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization, GlobalMaxPooling2D
from tensorflow.keras.optimizers import Adam,Adadelta,RMSprop,Adagrad
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau,EarlyStopping
from tensorflow.keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation
from tensorflow.keras.applications.imagenet_utils import preprocess_input
import numpy as np
import argparse
import cv2
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from tensorflow.keras.models import Model, Sequential
from sklearn.model_selection import StratifiedKFold
import scipy
import skimage
from skimage.transform import resize
import random
import os
import seaborn as sns
from tqdm import tqdm


# Import the necessary packages
from __future__ import print_function
import numpy as np
import argparse
import matplotlib.pyplot as plt
import cv2
import cv2 as cv
from matplotlib import pyplot as plt
from skimage import data, io
from skimage.util import img_as_ubyte
from skimage.io import imshow, imread
from skimage.color import rgb2hsv, hsv2rgb
import matplotlib.patches as mpatches
from skimage import data
from skimage.filters import threshold_otsu
from skimage.segmentation import clear_border
from skimage.measure import label, regionprops
from skimage.morphology import closing, square
from skimage.color import label2rgb
from skimage.filters import threshold_mean

# %%
# Import the necessary packages
import cv2
import cv2 as cv
import numpy as np
import mahotas as mh
import mahotas.demos
import argparse
import time
import matplotlib.pyplot as plt
import tensorflow
import glob
import matplotlib.patches as mpatches
import random
import os
import seaborn as sns
import argparse
import imutils
import glob as glob
from matplotlib import pyplot as plt
#from __future__ import print_function
from warnings import filterwarnings

import scipy
from scipy import ndimage
from scipy.spatial.distance import euclidean
from imutils import perspective
from imutils import contours
from tqdm import tqdm
from pylab import imshow, show
from scipy.spatial import distance as dist
from imutils import perspective
from imutils import contours
from PIL import Image

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img, save_img, img_to_array
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam,SGD,RMSprop,Adamax
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization, GlobalMaxPooling2D
from tensorflow.keras.optimizers import Adam,Adadelta,RMSprop,Adagrad
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau,EarlyStopping
from tensorflow.keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation
from tensorflow.keras.applications.imagenet_utils import preprocess_input
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from skimage.draw import ellipse
#from skimage.measure import label, regionprops, regionprops_table
from skimage.transform import rotate
import pandas
from sklearn import preprocessing
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold


import skimage
from skimage import data
from skimage import data, io
from skimage.transform import resize
from skimage.util import img_as_ubyte
from skimage.io import imshow, imread
from skimage.color import rgb2hsv, hsv2rgb
from skimage import io, filters
from skimage.filters import threshold_otsu
from skimage.filters import threshold_mean
from skimage.segmentation import clear_border
from skimage.measure import label, regionprops, regionprops_table
from skimage.morphology import closing, square
from skimage.color import label2rgb
from skimage import measure
from skimage.color import rgb2hsv
from skimage.color import rgb2xyz
from skimage.color import rgb2rgbcie
from skimage.exposure import histogram

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# # Hasil Simulasi

# %%
#Print Total AFB
import os
from skimage import data, io
import matplotlib.pyplot as plt
dirCrop='/content/gdrive/MyDrive/Hasil Uji SK4/YOLOv7/TB 1+/exp01A-154'
dir=dirCrop
for path in os.listdir(dirCrop):
        image =io.imread(os.path.join(dir, path))
        plt.figure(figsize=(8, 5))
        plt.subplot(1, 2, 1), plt.title(os.path.basename(path)), plt.imshow(image), plt.axis('off')
print('Total Boxes (Cropped):', len(os.listdir(dirCrop)), 'AFB')

# %% [markdown]
# # **2. Getting Our Dataset**
#
# If you haven't followed the link to dataset given in description, here it is again [Trash Dataset](https://roboflow.com/as-waste)
#
# - Follow the link and sign in to your Roboflow account. If you haven't signed up before, first sign up and then sign in
# - Once you are login, click the **Download this Dataset** tab in the top right corner
# - A dialogue box will open, select the YOLOv7 format, check the **Show download code** option and press continue.
# - A download code will appear

# %%
#!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="zcDIgks11LAMc0lolfUP")
project = rf.workspace("citra").project("tes-j15gl")
dataset = project.version(11).download("yolov7")

# %%
#SCA AFB 371 images
#!pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="KoBPEdoIoyCqsLfB1mfo")
project = rf.workspace("suci-aulia").project("afb-test-y7")
dataset = project.version(9).download("yolov7")

# %%
#SCA AFB 120 images

from roboflow import Roboflow
rf = Roboflow(api_key="KoBPEdoIoyCqsLfB1mfo")
project = rf.workspace("suci-aulia").project("afb-test-y7")
dataset = project.version(2).download("yolov7")

# %% [markdown]
# # **3. Run YOLOv7 Training**

# %% [markdown]
# # 3.1 Getting our pretrained model, you can choose any model from below to fine-tune
#
# **Uncomment the model you want to finetune**
#
# There are five available model, uncomment the one which you want to train. For this we will be finetuning **yolov7.pt** model

# %%
# %cd /content/gdrive/MyDrive/37_Y7/yolov7

# %%
# %%bash
# #wget -P /content/gdrive/MyDrive/yolov7 https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt
# #wget -P /content/gdrive/MyDrive/yolov7 https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7x.pt
# wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-w6.pt
# # wget -P /content/gdrive/MyDrive/yolov7 https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-e6.pt
# # wget -P /content/gdrive/MyDrive/yolov7 https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-d6.pt
# # wget -P /content/gdrive/MyDrive/yolov7 https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-e6e.pt

# %% [markdown]
# # 3.2 Start Training
#
# **Note**
#
# [To get the full list of training arguments follow the link](https://github.com/WongKinYiu/yolov7/blob/main/train.py)
#
# Some important arguments to know
# - **configuration**: In the main yolov7 folder go to cfg/training folder and select the path of appropriate configuration file. Give the relative path to the file in **--cfg** argument
# - **data** the path to data folder, it will be automatically catered
# - **weights** path to pretrained weights given by **--weights** argument
#
#
# <br><br>
#
# **Note for resuming training from checkpoint** <br>
# By default, the checkpoints for the epoch are stored in folder, yolov7/runs/train, give the relative path to last epoch checkpoints

# %%
#wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)

# %%
pip install wandb

# %% [markdown]
# #Roboflow 37

# %% [markdown]
# ##Yolov7w6-371-110epoch-size1256

# %%
# %cd /content/gdrive/MyDrive/37_Y7/yolov7
# !python train_aux.py  --name Yolov7w6-371-110epoch-noresize --batch 4 --cfg /content/gdrive/MyDrive/37_Y7/yolov7/cfg/training/yolov7-w6.yaml --epochs 110 --img 1256 --data /content/gdrive/MyDrive/37_Y7/yolov7/tes-11/data.yaml --weights yolov7-w6.pt --hyp data/hyp.scratch.custom.yaml --device 0 --workers 8

# %% [markdown]
# ##Yolov7w6-371-200epoch-size1256

# %%
# %cd /content/gdrive/MyDrive/37_Y7/yolov7
# !python train_aux.py  --name Yolov7w6-371-200epoch-noresize --batch 4 --cfg /content/gdrive/MyDrive/37_Y7/yolov7/cfg/training/yolov7-w6.yaml --epochs 200 --img 1256 --data /content/gdrive/MyDrive/37_Y7/yolov7/tes-11/data.yaml --weights yolov7-w6.pt --hyp data/hyp.scratch.custom.yaml --device 0 --workers 8

# %%
# %c

# %% [markdown]
# ##Yolov7w6-371-120epoch-1256

# %%
# %cd /content/gdrive/MyDrive/37_Y7/yolov7
# !python train_aux.py  --name Yolov7w6-371-120epoch-noresize --batch 4 --cfg /content/gdrive/MyDrive/37_Y7/yolov7/cfg/training/yolov7-w6.yaml --epochs 120 --img 1256 --data /content/gdrive/MyDrive/37_Y7/yolov7/tes-11/data.yaml --weights yolov7-w6.pt --hyp data/hyp.scratch.custom.yaml --device 0 --workers 8

# %% [markdown]
# ##Yolov7w6-371-900epoch-1024

# %%
# %cd /content/gdrive/MyDrive/37_Y7/yolov7
# !python train_aux.py  --name Yolov7w6-371-900epoch-noresize --batch 4 --cfg /content/gdrive/MyDrive/37_Y7/yolov7/cfg/training/yolov7-w6.yaml --epochs 900 --img 1024 --data /content/gdrive/MyDrive/37_Y7/yolov7/tes-11/data.yaml --weights yolov7-w6.pt --hyp data/hyp.scratch.custom.yaml --device 0 --workers 8

# %% [markdown]
# ##Yolov7w6-371-10epoch-noresize

# %%
# %cd /content/gdrive/MyDrive/37_Y7/yolov7
# !python train_aux.py  --name Yolov7w6-371-10epoch-noresize --batch 2 --cfg /content/gdrive/MyDrive/37_Y7/yolov7/cfg/training/yolov7-w6.yaml --epochs 10 --img 1024 --data /content/gdrive/MyDrive/37_Y7/yolov7/tes-11/data.yaml --weights yolov7-w6.pt --hyp data/hyp.scratch.custom.yaml --device 0 --workers 8

# %% [markdown]
# ##Yolov7w6-371-60epoch-noresize

# %%
# %cd /content/gdrive/MyDrive/37_Y7/yolov7
# !python train_aux.py  --name Yolov7w6-371-60epoch-noresize --batch 2 --cfg /content/gdrive/MyDrive/37_Y7/yolov7/cfg/training/yolov7-w6.yaml --epochs 60 --img 2000 --data /content/gdrive/MyDrive/37_Y7/yolov7/tes-11/data.yaml --weights yolov7-w6.pt --hyp data/hyp.scratch.custom.yaml --device 0 --workers 8

# %% [markdown]
# ##Juli

# %%
# %cd /content/gdrive/MyDrive/yolov7
# !python train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 55 --data {dataset.location}/data.yaml --weights 'yolov7.pt' --device 0

# %%
# %cd /content/gdrive/MyDrive/yolov7
# !python train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 3200 --data {dataset.location}/data.yaml --weights 'yolov7.pt' --device 0

# %%
#Download pemodelan
#export your model's weights for future use
from google.colab import files
#files.download('./runs/train/exp/weights/best.pt')
files.download('./runs/train/exp3/weights/epoch_3199.pt')

# %% [markdown]
# # **4. Evaluation**
#
# - Note the checkpoints from training will be stored by default in runs/train/exp. Take the path of the latest checkpoint
#
# We can evaluate the performance of our custom training using the provided evalution script.
#
# Note we can adjust the below custom arguments. For details, see [the arguments accepted by detect.py](https://github.com/WongKinYiu/yolov7/blob/main/detect.py#L154).

# %% [markdown]
# # 4.1 F1 and Precision Recall Curve

# %%
from IPython.display import Image
#display(Image("/content/gdrive/MyDrive/yolov7/runs/train/exp3/F1_curve.png", width=400, height=400))
#display(Image("/content/gdrive/MyDrive/yolov7/runs/train/exp3/PR_curve.png", width=400, height=400))
display(Image("/content/gdrive/MyDrive/yolov7/runs/train/exp3/confusion_matrix.png", width=500, height=500))

# %% [markdown]
# # 5.1.1 Run the below cell to evaluate on test images

# %% [markdown]
# #AGUSTUS

# %% [markdown]
# #YOLO7 W6

# %%
# %cd /content/gdrive/MyDrive/37_Y7/yolov7

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/Trial

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/Trial

# %%
#-----------------FOLDER INFORMATION----------------
import os
from keras.preprocessing import image
# getting & setting (chapter-4)
#Import the necessary packages
from __future__ import print_function
import argparse
import cv2
# Import the necessary packages
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from matplotlib import pyplot as plt
from skimage import data, io
from skimage.util import img_as_ubyte
from PIL import Image

def key_func(x):
  return os.path.split(x)[-1]


#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A156" #10imgs
#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A164" #2imgs
dir = "/content/gdrive/MyDrive/37_Y7/yolov7/crop"
initial_count = 0
ARTEFACT=0
BLUEAFB=0
FUNGI=0
REDAFB=0

folderPath = os.path.join(dir)
for path in sorted(os.listdir(dir)):
  img =io.imread(os.path.join(dir, path))
  ori =io.imread(os.path.join(dir, path))
  img= cv2.resize(img, (64, 64))
  img = np.asarray(img)
  #plt.imshow(img),plt.title("Predicted Result"), plt.axis('off')
  img = np.expand_dims(img, axis=0)
  from keras.models import load_model
  saved_model = load_model(r"/content/gdrive/MyDrive/DLStage2_50_10.h5")

  output = saved_model.predict(img)
  #labels = ['ARTEFACT','BLUEAFB','FUNGI','REDAFB']
  if output[0][0] > output[0][1]:
    #print("ARTEFACT")
    ARTEFACT += 1
  elif output[0][1] > output[0][2]:
    BLUEAFB += 1
    #print('BLUEAFB')
  elif output[0][2] > output[0][3]:
    FUNGI += 1
    #print('FUNGI')
  else:
    REDAFB += 1
    #print('BLUEAFB')

  initial_count += 1

print("ARTEFACT:",ARTEFACT, 'image(s)')
print("BLUEAFB :",BLUEAFB, 'image(s)')
print("FUNGI   :",FUNGI, 'image(s)')
print("REDAFB  :",REDAFB, 'image(s)')

#2ndClassification  of OBJECTS
'''
if(ARTEFACT>BLUEAFB) and (ARTEFACT>FUNGI) and (ARTEFACT>REDAFB):
  Object=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTGREEN_EX+ " Good Staining"
elif (BLUEAFB>BLUEAFB) and (BLUEAFB>FUNGI) and (BLUEAFB>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
elif (FUNGI>BLUEAFB) and (FUNGI>Over) and (FUNGI>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
else:
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Over Staining"
'''
'''
  if os.path.isfile(os.path.join(dir, path)):
    plt.figure(num=None, figsize=(16,16))
    plt.subplot(1,2,1), plt.title(os.path.basename(path)), plt.imshow(ori), plt.axis('off')
    #plt.subplot(1,2,2), plt.title("Predicted Result"), plt.imshow(img), plt.axis('off')
    # show the output image
'''
print(" ")
print("---------------------------------")
print('\033[1m' +Fore.BLACK+"Path ID           :",os.path.basename(dir))
print('\033[1m' +Fore.BLACK+"Number of Datasets:",initial_count)

#print('\033[1m' +"Quality of Ziehl-Neelsen Staining:")
#print('\033[1m' +ZNStain)

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/371_Y7/yolov7/yolov7/runs/train/Yolov7w6-37-60epoch-noresize3/weights/best.pt --conf 0.5 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25051901A-35

# %% [markdown]
# ##2+

# %% [markdown]
# ###TB+2/25095201A-310

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201A-310

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/371_Y7/yolov7/yolov7/runs/train/Yolov7w6-37-60epoch-noresize3/weights/best.pt --conf 0.5 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201B-310

# %% [markdown]
# ##+3

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A10-203


#-----------------FOLDER INFORMATION----------------
import os
from keras.preprocessing import image
# getting & setting (chapter-4)
#Import the necessary packages
from __future__ import print_function
import argparse
import cv2
# Import the necessary packages
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from matplotlib import pyplot as plt
from skimage import data, io
from skimage.util import img_as_ubyte
from PIL import Image

def key_func(x):
  return os.path.split(x)[-1]


#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A156" #10imgs
#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A164" #2imgs
dir = "/content/gdrive/MyDrive/37_Y7/yolov7/crop"
initial_count = 0
ARTEFACT=0
BLUEAFB=0
FUNGI=0
REDAFB=0

folderPath = os.path.join(dir)
for path in sorted(os.listdir(dir)):
  img =io.imread(os.path.join(dir, path))
  ori =io.imread(os.path.join(dir, path))
  img= cv2.resize(img, (64, 64))
  img = np.asarray(img)
  #plt.imshow(img),plt.title("Predicted Result"), plt.axis('off')
  img = np.expand_dims(img, axis=0)
  from keras.models import load_model
  saved_model = load_model(r"/content/gdrive/MyDrive/DLStage2_50_10.h5")

  output = saved_model.predict(img)
  #labels = ['ARTEFACT','BLUEAFB','FUNGI','REDAFB']
  if output[0][0] > output[0][1]:
    #print("ARTEFACT")
    ARTEFACT += 1
  elif output[0][1] > output[0][2]:
    BLUEAFB += 1
    #print('BLUEAFB')
  elif output[0][2] > output[0][3]:
    FUNGI += 1
    #print('FUNGI')
  else:
    REDAFB += 1
    #print('BLUEAFB')

  initial_count += 1

print("ARTEFACT:",ARTEFACT, 'image(s)')
print("BLUEAFB :",BLUEAFB, 'image(s)')
print("FUNGI   :",FUNGI, 'image(s)')
print("REDAFB  :",REDAFB, 'image(s)')

#2ndClassification  of OBJECTS
'''
if(ARTEFACT>BLUEAFB) and (ARTEFACT>FUNGI) and (ARTEFACT>REDAFB):
  Object=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTGREEN_EX+ " Good Staining"
elif (BLUEAFB>BLUEAFB) and (BLUEAFB>FUNGI) and (BLUEAFB>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
elif (FUNGI>BLUEAFB) and (FUNGI>Over) and (FUNGI>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
else:
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Over Staining"
'''
'''
  if os.path.isfile(os.path.join(dir, path)):
    plt.figure(num=None, figsize=(16,16))
    plt.subplot(1,2,1), plt.title(os.path.basename(path)), plt.imshow(ori), plt.axis('off')
    #plt.subplot(1,2,2), plt.title("Predicted Result"), plt.imshow(img), plt.axis('off')
    # show the output image
'''
print(" ")
print("---------------------------------")
print('\033[1m' +Fore.BLACK+"Path ID           :",os.path.basename(dir))
print('\033[1m' +Fore.BLACK+"Number of Datasets:",initial_count)

#print('\033[1m' +"Quality of Ziehl-Neelsen Staining:")
#print('\033[1m' +ZNStain)

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-200epoch-noresize3/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A10-203

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-120epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A10-203

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-60epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A10-203

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-900epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A10-203

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A10-203

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/best_16_1200.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A10-203

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-37-1500epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A10-203

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/371_Y7/yolov7/yolov7/runs/train/Yolov7w6-37-60epoch-noresize3/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A10-203

# %% [markdown]
# ##Negative

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/371_Y7/yolov7/yolov7/runs/train/Yolov7w6-37-60epoch-noresize3/weights/best.pt --conf 0.4 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/371_Y7/yolov7/yolov7/runs/train/Yolov7w6-37-60epoch-noresize3/weights/best.pt --conf 0.3 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/371_Y7/yolov7/yolov7/runs/train/Yolov7w6-37-60epoch-noresize3/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/yolov7/crop/*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/371_Y7/yolov7/yolov7/runs/train/Yolov7w6-37-60epoch-noresize3/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %% [markdown]
# #Testing Conf=0.1

# %% [markdown]
# ##Negative

# %% [markdown]
# ### NEGATIF/25012301A-356

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
#-----------------FOLDER INFORMATION----------------
import os
from keras.preprocessing import image
# getting & setting (chapter-4)
#Import the necessary packages
from __future__ import print_function
import argparse
import cv2
# Import the necessary packages
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from matplotlib import pyplot as plt
from skimage import data, io
from skimage.util import img_as_ubyte
from PIL import Image

def key_func(x):
  return os.path.split(x)[-1]


#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A156" #10imgs
#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A164" #2imgs
dir = "/content/gdrive/MyDrive/37_Y7/yolov7/crop"
initial_count = 0
ARTEFACT=0
BLUEAFB=0
FUNGI=0
REDAFB=0

folderPath = os.path.join(dir)
for path in sorted(os.listdir(dir)):
  img =io.imread(os.path.join(dir, path))
  ori =io.imread(os.path.join(dir, path))
  img= cv2.resize(img, (64, 64))
  img = np.asarray(img)
  #plt.imshow(img),plt.title("Predicted Result"), plt.axis('off')
  img = np.expand_dims(img, axis=0)
  from keras.models import load_model
  saved_model = load_model(r"/content/gdrive/MyDrive/DLStage2_50_10.h5")

  output = saved_model.predict(img)
  #labels = ['ARTEFACT','BLUEAFB','FUNGI','REDAFB']
  if output[0][0] > output[0][1]:
    #print("ARTEFACT")
    ARTEFACT += 1
  elif output[0][1] > output[0][2]:
    BLUEAFB += 1
    #print('BLUEAFB')
  elif output[0][2] > output[0][3]:
    FUNGI += 1
    #print('FUNGI')
  else:
    REDAFB += 1
    #print('BLUEAFB')

  initial_count += 1

print("ARTEFACT:",ARTEFACT, 'image(s)')
print("BLUEAFB :",BLUEAFB, 'image(s)')
print("FUNGI   :",FUNGI, 'image(s)')
print("REDAFB  :",REDAFB, 'image(s)')

#2ndClassification  of OBJECTS
'''
if(ARTEFACT>BLUEAFB) and (ARTEFACT>FUNGI) and (ARTEFACT>REDAFB):
  Object=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTGREEN_EX+ " Good Staining"
elif (BLUEAFB>BLUEAFB) and (BLUEAFB>FUNGI) and (BLUEAFB>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
elif (FUNGI>BLUEAFB) and (FUNGI>Over) and (FUNGI>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
else:
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Over Staining"
'''
'''
  if os.path.isfile(os.path.join(dir, path)):
    plt.figure(num=None, figsize=(16,16))
    plt.subplot(1,2,1), plt.title(os.path.basename(path)), plt.imshow(ori), plt.axis('off')
    #plt.subplot(1,2,2), plt.title("Predicted Result"), plt.imshow(img), plt.axis('off')
    # show the output image
'''
print(" ")
print("---------------------------------")
print('\033[1m' +Fore.BLACK+"Path ID           :",os.path.basename(dir))
print('\033[1m' +Fore.BLACK+"Number of Datasets:",initial_count)

#print('\033[1m' +"Quality of Ziehl-Neelsen Staining:")
#print('\033[1m' +ZNStain)

# %% [markdown]
# ### NEGATIF/25014002B-360

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %% [markdown]
# ### NEGATIF/25022602A-417

# %%
# Run evaluation

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25022602A-417

# %% [markdown]
# ###NEGATIF/25049001 A 20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001A-20

# %% [markdown]
# ###NEGATIF/25049001B-20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001B-20

# %% [markdown]
# ### NEGATIF/25065001B-125

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25065001B-125

# %% [markdown]
# ### NEGATIF/25066602A-153

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25066602A-153

# %% [markdown]
# ###NEGATIF/25090106A-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106A-274

# %% [markdown]
# ###NEGATIF/25090106B-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106B-274

# %% [markdown]
# ###NEGATIF/25077801B-193

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25077801B-193

# %% [markdown]
# ###NEGATIF/25078502A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25078502A-230

# %% [markdown]
# ###NEGATIF/25084301A-229

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25084301A-229

# %% [markdown]
# ###NEGATIF/25089101B-248

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25089101B-248

# %% [markdown]
# Testing epoch=110

# %% [markdown]
# ##Scanty

# %% [markdown]
# ### /Scanty/25001201A-206

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25001201A-206

# %% [markdown]
# ###/Scanty/25014101B-355

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014101B-355

# %% [markdown]
# ###/Scanty/25014801A-367

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014801A-367

# %% [markdown]
# ###/Scanty/25007801B-285_9AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25007801B-285_9AFB

# %% [markdown]
# ### /Scanty/25005101B-229_4AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25005101B-229_4AFB

# %% [markdown]
# ### /Scanty/25018001B-392

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392

# %% [markdown]
# ### /Scanty/25070501A156_21AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501A156_21AFB

# %% [markdown]
# ###/Scanty/25070501B156_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501B156_6AFB

# %% [markdown]
# ###/Scanty/25070801A164_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070801A164_6AFB

# %% [markdown]
# ###/Scanty/25080301A201_12AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25080301A201_12AFB

# %% [markdown]
# ###/Scanty/25094501A303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501A303_6AFB

# %% [markdown]
# ###/Scanty/25094501B303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501B303_6AFB

# %% [markdown]
# ##TB+1

# %% [markdown]
# ### /TB+1/25001001B-204

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25001001B-204

# %% [markdown]
# ### /TB+1/25005001A-220

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25005001A-220

# %% [markdown]
# ### /TB+1/25012501A-342

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25012501A-342

# %% [markdown]
# ###/TB+1/25013501A-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25013501A-344

# %% [markdown]
# ###/TB+1/25018601B-399

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25018601B-399

# %% [markdown]
# ### /TB+1/25023301A-420

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25023301A-420

# %% [markdown]
# ### /TB+1/25051901A-35

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25051901A-35

# %% [markdown]
# ###/TB+1/25070602A-154

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25070602A-154

# %% [markdown]
# ###/TB+1/25080301B-201

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25080301B-201

# %% [markdown]
# ###TB+1/25095601A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601A-313

# %% [markdown]
# ###/TB+1/25095601B-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601B-313

# %% [markdown]
# ##TB2+

# %% [markdown]
# ###TB+2/25001101B-205

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25001101B-205

# %% [markdown]
# ###/TB+2/25005201A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25005201A-230

# %% [markdown]
# ### /TB+2/25007901A-286

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25007901A-286

# %% [markdown]
# ###/TB+2/25008001A-294

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008001A-294

# %% [markdown]
# ###TB+2/25008101B-295

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008101B-295

# %% [markdown]
# ###/TB+2/25008201A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008201A-313

# %% [markdown]
# ###/TB+2/25009704A-33

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25009704A-33

# %% [markdown]
# ###/TB+2/25009704B-33

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25009704B-33

# %% [markdown]
# ###/TB+2/25012101A-331

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25012101A-331

# %% [markdown]
# ###/TB+2/25013501B-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013501B-344

# %% [markdown]
# ###/TB+2/25013901B-357

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013901B-357

# %% [markdown]
# ###/TB+2/25017301A-371

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25017301A-371

# %% [markdown]
# ###/TB+2/25095201A-310

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201A-310

# %% [markdown]
# ###/TB+2/25095201B-310

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201B-310

# %% [markdown]
# ##TB3+

# %% [markdown]
# ### TB+3/25000901A1-203

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A1-203

# %% [markdown]
# ### TB+3/25004901A1-219

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25004901A1-219

# %% [markdown]
# ###TB+3/25005401B1-240

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25005401B1-240

# %% [markdown]
# ###TB+3/25006901A1-265

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25006901A1-265

# %% [markdown]
# ###/TB+3/25008101A1-295

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25008101A1-295

# %% [markdown]
# ###/TB+3/25008501A1-299

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25008501A1-299

# %% [markdown]
# ### /TB+3/25009801B1-309

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25009801B1-309

# %% [markdown]
# ###/TB+3/25012101B1-331

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25012101B1-331

# %% [markdown]
# ###TB+3/25021601A1-401

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25021601A1-401

# %% [markdown]
# ###/TB+3/25023901A-423

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25023901A-423

# %% [markdown]
# ###/TB+3/25024001A-425

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25024001A-425

# %% [markdown]
# ###/TB+3/BlindTB3/25080801B-209

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25080801B-209

# %% [markdown]
# ###/TB+3/BlindTB3/25066601B-131

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25066601B-131

# %% [markdown]
# ###/TB+3/BlindTB3/25050901B-74

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25050901B-74

# %% [markdown]
# ###/TB+3/BlindTB3/25050901A-74

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25050901A-74

# %% [markdown]
# #Testing Conf=0.2

# %% [markdown]
# ##Negative

# %% [markdown]
# ### NEGATIF/25012301A-356

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
#-----------------FOLDER INFORMATION----------------
import os
from keras.preprocessing import image
# getting & setting (chapter-4)
#Import the necessary packages
from __future__ import print_function
import argparse
import cv2
# Import the necessary packages
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from matplotlib import pyplot as plt
from skimage import data, io
from skimage.util import img_as_ubyte
from PIL import Image

def key_func(x):
  return os.path.split(x)[-1]


#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A156" #10imgs
#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A164" #2imgs
dir = "/content/gdrive/MyDrive/37_Y7/yolov7/crop"
initial_count = 0
ARTEFACT=0
BLUEAFB=0
FUNGI=0
REDAFB=0

folderPath = os.path.join(dir)
for path in sorted(os.listdir(dir)):
  img =io.imread(os.path.join(dir, path))
  ori =io.imread(os.path.join(dir, path))
  img= cv2.resize(img, (64, 64))
  img = np.asarray(img)
  #plt.imshow(img),plt.title("Predicted Result"), plt.axis('off')
  img = np.expand_dims(img, axis=0)
  from keras.models import load_model
  saved_model = load_model(r"/content/gdrive/MyDrive/DLStage2_50_10.h5")

  output = saved_model.predict(img)
  #labels = ['ARTEFACT','BLUEAFB','FUNGI','REDAFB']
  if output[0][0] > output[0][1]:
    #print("ARTEFACT")
    ARTEFACT += 1
  elif output[0][1] > output[0][2]:
    BLUEAFB += 1
    #print('BLUEAFB')
  elif output[0][2] > output[0][3]:
    FUNGI += 1
    #print('FUNGI')
  else:
    REDAFB += 1
    #print('BLUEAFB')

  initial_count += 1

print("ARTEFACT:",ARTEFACT, 'image(s)')
print("BLUEAFB :",BLUEAFB, 'image(s)')
print("FUNGI   :",FUNGI, 'image(s)')
print("REDAFB  :",REDAFB, 'image(s)')

#2ndClassification  of OBJECTS
'''
if(ARTEFACT>BLUEAFB) and (ARTEFACT>FUNGI) and (ARTEFACT>REDAFB):
  Object=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTGREEN_EX+ " Good Staining"
elif (BLUEAFB>BLUEAFB) and (BLUEAFB>FUNGI) and (BLUEAFB>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
elif (FUNGI>BLUEAFB) and (FUNGI>Over) and (FUNGI>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
else:
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Over Staining"
'''
'''
  if os.path.isfile(os.path.join(dir, path)):
    plt.figure(num=None, figsize=(16,16))
    plt.subplot(1,2,1), plt.title(os.path.basename(path)), plt.imshow(ori), plt.axis('off')
    #plt.subplot(1,2,2), plt.title("Predicted Result"), plt.imshow(img), plt.axis('off')
    # show the output image
'''
print(" ")
print("---------------------------------")
print('\033[1m' +Fore.BLACK+"Path ID           :",os.path.basename(dir))
print('\033[1m' +Fore.BLACK+"Number of Datasets:",initial_count)

#print('\033[1m' +"Quality of Ziehl-Neelsen Staining:")
#print('\033[1m' +ZNStain)

# %% [markdown]
# ### NEGATIF/25014002B-360

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %% [markdown]
# ### NEGATIF/25022602A-417

# %%
# Run evaluation

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25022602A-417

# %% [markdown]
# ###NEGATIF/25049001 A 20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001A-20

# %% [markdown]
# ###NEGATIF/25049001B-20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001B-20

# %% [markdown]
# ### NEGATIF/25065001B-125

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25065001B-125

# %% [markdown]
# ### NEGATIF/25066602A-153

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25066602A-153

# %% [markdown]
# ###NEGATIF/25090106A-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106A-274

# %% [markdown]
# ###NEGATIF/25090106B-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106B-274

# %% [markdown]
# ###NEGATIF/25077801B-193

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25077801B-193

# %% [markdown]
# ###NEGATIF/25078502A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25078502A-230

# %% [markdown]
# ###NEGATIF/25084301A-229

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25084301A-229

# %% [markdown]
# ###NEGATIF/25089101B-248

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25089101B-248

# %% [markdown]
# Testing epoch=110

# %% [markdown]
# ##TB+1

# %% [markdown]
# ### /TB+1/25001001B-204

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25001001B-204

# %%
#Print Total AFB
import os
from skimage import data, io
import matplotlib.pyplot as plt
dirCrop='/content/gdrive/MyDrive/yolov7/crop'
dir=dirCrop
'''
for path in os.listdir(dirCrop):
        image =io.imread(os.path.join(dir, path))
        plt.figure(figsize=(8, 5))
        plt.subplot(1, 2, 1), plt.title(os.path.basename(path)), plt.imshow(image), plt.axis('off')'
'''
print('Total Boxes (Cropped):', len(os.listdir(dirCrop)), 'AFB')

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25001001B-204

# %% [markdown]
# ### /TB+1/25005001A-220

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25005001A-220

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/runs/train/exp/weights/best_227.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25005001A-220

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/runs/train/exp/weights/best_227.pt --conf 0.5 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25005001A-220

# %% [markdown]
# ### /TB+1/25012501A-342

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25012501A-342

# %% [markdown]
# ###/TB+1/25013501A-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25013501A-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/runs/train/exp/weights/best_227.pt --conf 0.5 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25013501A-344

# %% [markdown]
# ###/TB+1/25018601B-399

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25018601B-399

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/runs/train/exp/weights/best_227.pt --conf 0.5 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25018601B-399

# %% [markdown]
# ### /TB+1/25023301A-420

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25023301A-420

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/runs/train/exp/weights/best_227.pt --conf 0.5 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25023301A-420

# %% [markdown]
# ### /TB+1/25051901A-35

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25051901A-35

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/runs/train/exp/weights/best_227.pt --conf 0.5 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25051901A-35

# %% [markdown]
# ###/TB+1/25070602A-154

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25070602A-154

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/runs/train/exp/weights/best_227.pt --conf 0.5 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25070602A-154

# %% [markdown]
# ###/TB+1/25080301B-201

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25080301B-201

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/runs/train/exp/weights/best_227.pt --conf 0.5 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25080301B-201

# %% [markdown]
# ###TB+1/25095601A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/runs/train/exp/weights/best_227.pt --conf 0.5 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601A-313

# %% [markdown]
# ###/TB+1/25095601B-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601B-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601B-313

# %% [markdown]
# ##TB2+

# %% [markdown]
# ###TB+2/25001101B-205

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25001101B-205

# %% [markdown]
# ###/TB+2/25005201A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25005201A-230

# %% [markdown]
# ### /TB+2/25007901A-286

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25007901A-286

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25007901A-286

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25007901A-286

# %% [markdown]
# ###/TB+2/25008001A-294

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008001A-294

# %% [markdown]
# ###TB+2/25008101B-295

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008101B-295

# %% [markdown]
# ###/TB+2/25008201A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008201A-313

# %% [markdown]
# ###/TB+2/25009704A-33

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25009704A-33

# %% [markdown]
# ###/TB+2/25009704B-33

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25009704B-33

# %% [markdown]
# ###/TB+2/25012101A-331

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25012101A-331

# %% [markdown]
# ###/TB+2/25013501B-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013501B-344

# %% [markdown]
# ###/TB+2/25013901B-357

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013901B-357

# %% [markdown]
# ###/TB+2/25017301A-371

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25017301A-371

# %% [markdown]
# ###/TB+2/25095201A-310

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201A-310

# %% [markdown]
# ###/TB+2/25095201B-310

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201B-310

# %% [markdown]
# ##Scanty

# %% [markdown]
# ### /Scanty/25001201A-206

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25001201A-206

# %% [markdown]
# ###/Scanty/25014101B-355

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014101B-355

# %% [markdown]
# ###/Scanty/25014801A-367

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014801A-367

# %% [markdown]
# ###/Scanty/25007801B-285_9AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25007801B-285_9AFB

# %% [markdown]
# ### /Scanty/25005101B-229_4AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25005101B-229_4AFB

# %% [markdown]
# ### /Scanty/25018001B-392

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392

# %% [markdown]
# ### /Scanty/25070501A156_21AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501A156_21AFB

# %% [markdown]
# ###/Scanty/25070501B156_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501B156_6AFB

# %% [markdown]
# ###/Scanty/25070801A164_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070801A164_6AFB

# %% [markdown]
# ###/Scanty/25080301A201_12AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25080301A201_12AFB

# %% [markdown]
# ###/Scanty/25094501A303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501A303_6AFB

# %% [markdown]
# ###/Scanty/25094501B303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501B303_6AFB

# %% [markdown]
# ##TB3+

# %% [markdown]
# ### TB+3/25000901A1-203

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A1-203

# %% [markdown]
# ### TB+3/25004901A1-219

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25004901A1-219

# %% [markdown]
# ###TB+3/25005401B1-240

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25005401B1-240

# %% [markdown]
# ###TB+3/25006901A1-265

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25006901A1-265

# %% [markdown]
# ###/TB+3/25008101A1-295

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25008101A1-295

# %% [markdown]
# ###/TB+3/25008501A1-299

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25008501A1-299

# %% [markdown]
# ### /TB+3/25009801B1-309

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25009801B1-309

# %% [markdown]
# ###/TB+3/25012101B1-331

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25012101B1-331

# %% [markdown]
# ###TB+3/25021601A1-401

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25021601A1-401

# %% [markdown]
# ###/TB+3/25023901A-423

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25023901A-423

# %% [markdown]
# ###/TB+3/25024001A-425

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25024001A-425

# %% [markdown]
# ###/TB+3/BlindTB3/25080801B-209

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25080801B-209

# %% [markdown]
# ###/TB+3/BlindTB3/25066601B-131

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25066601B-131

# %% [markdown]
# ###/TB+3/BlindTB3/25050901B-74

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25050901B-74

# %% [markdown]
# ###/TB+3/BlindTB3/25050901A-74

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25050901A-74

# %% [markdown]
# #Testing Conf=0.15

# %% [markdown]
# ##Negative

# %% [markdown]
# ### NEGATIF/25012301A-356

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
#-----------------FOLDER INFORMATION----------------
import os
from keras.preprocessing import image
# getting & setting (chapter-4)
#Import the necessary packages
from __future__ import print_function
import argparse
import cv2
# Import the necessary packages
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from matplotlib import pyplot as plt
from skimage import data, io
from skimage.util import img_as_ubyte
from PIL import Image

def key_func(x):
  return os.path.split(x)[-1]


#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A156" #10imgs
#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A164" #2imgs
dir = "/content/gdrive/MyDrive/37_Y7/yolov7/crop"
initial_count = 0
ARTEFACT=0
BLUEAFB=0
FUNGI=0
REDAFB=0

folderPath = os.path.join(dir)
for path in sorted(os.listdir(dir)):
  img =io.imread(os.path.join(dir, path))
  ori =io.imread(os.path.join(dir, path))
  img= cv2.resize(img, (64, 64))
  img = np.asarray(img)
  #plt.imshow(img),plt.title("Predicted Result"), plt.axis('off')
  img = np.expand_dims(img, axis=0)
  from keras.models import load_model
  saved_model = load_model(r"/content/gdrive/MyDrive/DLStage2_50_10.h5")

  output = saved_model.predict(img)
  #labels = ['ARTEFACT','BLUEAFB','FUNGI','REDAFB']
  if output[0][0] > output[0][1]:
    #print("ARTEFACT")
    ARTEFACT += 1
  elif output[0][1] > output[0][2]:
    BLUEAFB += 1
    #print('BLUEAFB')
  elif output[0][2] > output[0][3]:
    FUNGI += 1
    #print('FUNGI')
  else:
    REDAFB += 1
    #print('BLUEAFB')

  initial_count += 1

print("ARTEFACT:",ARTEFACT, 'image(s)')
print("BLUEAFB :",BLUEAFB, 'image(s)')
print("FUNGI   :",FUNGI, 'image(s)')
print("REDAFB  :",REDAFB, 'image(s)')

#2ndClassification  of OBJECTS
'''
if(ARTEFACT>BLUEAFB) and (ARTEFACT>FUNGI) and (ARTEFACT>REDAFB):
  Object=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTGREEN_EX+ " Good Staining"
elif (BLUEAFB>BLUEAFB) and (BLUEAFB>FUNGI) and (BLUEAFB>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
elif (FUNGI>BLUEAFB) and (FUNGI>Over) and (FUNGI>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
else:
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Over Staining"
'''
'''
  if os.path.isfile(os.path.join(dir, path)):
    plt.figure(num=None, figsize=(16,16))
    plt.subplot(1,2,1), plt.title(os.path.basename(path)), plt.imshow(ori), plt.axis('off')
    #plt.subplot(1,2,2), plt.title("Predicted Result"), plt.imshow(img), plt.axis('off')
    # show the output image
'''
print(" ")
print("---------------------------------")
print('\033[1m' +Fore.BLACK+"Path ID           :",os.path.basename(dir))
print('\033[1m' +Fore.BLACK+"Number of Datasets:",initial_count)

#print('\033[1m' +"Quality of Ziehl-Neelsen Staining:")
#print('\033[1m' +ZNStain)

# %% [markdown]
# ### NEGATIF/25014002B-360

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %% [markdown]
# ### NEGATIF/25022602A-417

# %%
# Run evaluation

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25022602A-417

# %% [markdown]
# ###NEGATIF/25049001 A 20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001A-20

# %% [markdown]
# ###NEGATIF/25049001B-20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001B-20

# %% [markdown]
# ### NEGATIF/25065001B-125

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25065001B-125

# %% [markdown]
# ### NEGATIF/25066602A-153

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25066602A-153

# %% [markdown]
# ###NEGATIF/25090106A-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106A-274

# %% [markdown]
# ###NEGATIF/25090106B-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106B-274

# %% [markdown]
# ###NEGATIF/25077801B-193

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25077801B-193

# %% [markdown]
# ###NEGATIF/25078502A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25078502A-230

# %% [markdown]
# ###NEGATIF/25084301A-229

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25084301A-229

# %% [markdown]
# ###NEGATIF/25089101B-248

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25089101B-248

# %% [markdown]
# Testing epoch=110

# %% [markdown]
# ##Scanty

# %% [markdown]
# ### /Scanty/25001201A-206

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25001201A-206

# %% [markdown]
# ###/Scanty/25014101B-355

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014101B-355

# %% [markdown]
# ###/Scanty/25014801A-367

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014801A-367

# %% [markdown]
# ###/Scanty/25007801B-285_9AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25007801B-285_9AFB

# %% [markdown]
# ### /Scanty/25005101B-229_4AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25005101B-229_4AFB

# %% [markdown]
# ### /Scanty/25018001B-392

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392

# %% [markdown]
# ### /Scanty/25070501A156_21AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501A156_21AFB

# %% [markdown]
# ###/Scanty/25070501B156_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501B156_6AFB

# %% [markdown]
# ###/Scanty/25070801A164_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070801A164_6AFB

# %% [markdown]
# ###/Scanty/25080301A201_12AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25080301A201_12AFB

# %% [markdown]
# ###/Scanty/25094501A303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501A303_6AFB

# %% [markdown]
# ###/Scanty/25094501B303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501B303_6AFB

# %% [markdown]
# ##TB+1

# %% [markdown]
# ### /TB+1/25001001B-204

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25001001B-204

# %% [markdown]
# ### /TB+1/25005001A-220

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25005001A-220

# %% [markdown]
# ### /TB+1/25012501A-342

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25012501A-342

# %% [markdown]
# ###/TB+1/25013501A-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25013501A-344

# %% [markdown]
# ###/TB+1/25018601B-399

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25018601B-399

# %% [markdown]
# ### /TB+1/25023301A-420

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25023301A-420

# %% [markdown]
# ### /TB+1/25051901A-35

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25051901A-35

# %% [markdown]
# ###/TB+1/25070602A-154

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25070602A-154

# %% [markdown]
# ###/TB+1/25080301B-201

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25080301B-201

# %% [markdown]
# ###TB+1/25095601A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601A-313

# %% [markdown]
# ###/TB+1/25095601B-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601B-313

# %% [markdown]
# ##TB2+

# %% [markdown]
# ###TB+2/25001101B-205

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25001101B-205

# %% [markdown]
# ###/TB+2/25005201A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25005201A-230

# %% [markdown]
# ### /TB+2/25007901A-286

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25007901A-286

# %% [markdown]
# ###/TB+2/25008001A-294

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008001A-294

# %% [markdown]
# ###TB+2/25008101B-295

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008101B-295

# %% [markdown]
# ###/TB+2/25008201A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008201A-313

# %% [markdown]
# ###/TB+2/25009704A-33

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25009704A-33

# %% [markdown]
# ###/TB+2/25009704B-33

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25009704B-33

# %% [markdown]
# ###/TB+2/25012101A-331

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25012101A-331

# %% [markdown]
# ###/TB+2/25013501B-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013501B-344

# %% [markdown]
# ###/TB+2/25013901B-357

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013901B-357

# %% [markdown]
# ###/TB+2/25017301A-371

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25017301A-371

# %% [markdown]
# ###/TB+2/25095201A-310

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201A-310

# %% [markdown]
# ###/TB+2/25095201B-310

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201B-310

# %% [markdown]
# ##TB3+

# %% [markdown]
# ### TB+3/25000901A1-203

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A1-203

# %% [markdown]
# ### TB+3/25004901A1-219

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25004901A1-219

# %% [markdown]
# ###TB+3/25005401B1-240

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25005401B1-240

# %% [markdown]
# ###TB+3/25006901A1-265

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25006901A1-265

# %% [markdown]
# ###/TB+3/25008101A1-295

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25008101A1-295

# %% [markdown]
# ###/TB+3/25008501A1-299

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25008501A1-299

# %% [markdown]
# ### /TB+3/25009801B1-309

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25009801B1-309

# %% [markdown]
# ###/TB+3/25012101B1-331

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25012101B1-331

# %% [markdown]
# ###TB+3/25021601A1-401

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25021601A1-401

# %% [markdown]
# ###/TB+3/25023901A-423

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25023901A-423

# %% [markdown]
# ###/TB+3/25024001A-425

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25024001A-425

# %% [markdown]
# ###/TB+3/BlindTB3/25080801B-209

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25080801B-209

# %% [markdown]
# ###/TB+3/BlindTB3/25066601B-131

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25066601B-131

# %% [markdown]
# ###/TB+3/BlindTB3/25050901B-74

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25050901B-74

# %% [markdown]
# ###/TB+3/BlindTB3/25050901A-74

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25050901A-74

# %% [markdown]
# #Testing Conf=0.16

# %% [markdown]
# ##Negative

# %% [markdown]
# ### NEGATIF/25012301A-356

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
#-----------------FOLDER INFORMATION----------------
import os
from keras.preprocessing import image
# getting & setting (chapter-4)
#Import the necessary packages
from __future__ import print_function
import argparse
import cv2
# Import the necessary packages
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from matplotlib import pyplot as plt
from skimage import data, io
from skimage.util import img_as_ubyte
from PIL import Image

def key_func(x):
  return os.path.split(x)[-1]


#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A156" #10imgs
#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A164" #2imgs
dir = "/content/gdrive/MyDrive/37_Y7/yolov7/crop"
initial_count = 0
ARTEFACT=0
BLUEAFB=0
FUNGI=0
REDAFB=0

folderPath = os.path.join(dir)
for path in sorted(os.listdir(dir)):
  img =io.imread(os.path.join(dir, path))
  ori =io.imread(os.path.join(dir, path))
  img= cv2.resize(img, (64, 64))
  img = np.asarray(img)
  #plt.imshow(img),plt.title("Predicted Result"), plt.axis('off')
  img = np.expand_dims(img, axis=0)
  from keras.models import load_model
  saved_model = load_model(r"/content/gdrive/MyDrive/DLStage2_50_10.h5")

  output = saved_model.predict(img)
  #labels = ['ARTEFACT','BLUEAFB','FUNGI','REDAFB']
  if output[0][0] > output[0][1]:
    #print("ARTEFACT")
    ARTEFACT += 1
  elif output[0][1] > output[0][2]:
    BLUEAFB += 1
    #print('BLUEAFB')
  elif output[0][2] > output[0][3]:
    FUNGI += 1
    #print('FUNGI')
  else:
    REDAFB += 1
    #print('BLUEAFB')

  initial_count += 1

print("ARTEFACT:",ARTEFACT, 'image(s)')
print("BLUEAFB :",BLUEAFB, 'image(s)')
print("FUNGI   :",FUNGI, 'image(s)')
print("REDAFB  :",REDAFB, 'image(s)')

#2ndClassification  of OBJECTS
'''
if(ARTEFACT>BLUEAFB) and (ARTEFACT>FUNGI) and (ARTEFACT>REDAFB):
  Object=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTGREEN_EX+ " Good Staining"
elif (BLUEAFB>BLUEAFB) and (BLUEAFB>FUNGI) and (BLUEAFB>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
elif (FUNGI>BLUEAFB) and (FUNGI>Over) and (FUNGI>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
else:
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Over Staining"
'''
'''
  if os.path.isfile(os.path.join(dir, path)):
    plt.figure(num=None, figsize=(16,16))
    plt.subplot(1,2,1), plt.title(os.path.basename(path)), plt.imshow(ori), plt.axis('off')
    #plt.subplot(1,2,2), plt.title("Predicted Result"), plt.imshow(img), plt.axis('off')
    # show the output image
'''
print(" ")
print("---------------------------------")
print('\033[1m' +Fore.BLACK+"Path ID           :",os.path.basename(dir))
print('\033[1m' +Fore.BLACK+"Number of Datasets:",initial_count)

#print('\033[1m' +"Quality of Ziehl-Neelsen Staining:")
#print('\033[1m' +ZNStain)

# %% [markdown]
# ### NEGATIF/25014002B-360

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %% [markdown]
# ### NEGATIF/25022602A-417

# %%
# Run evaluation

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25022602A-417

# %% [markdown]
# ###NEGATIF/25049001 A 20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001A-20

# %% [markdown]
# ###NEGATIF/25049001B-20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001B-20

# %% [markdown]
# ### NEGATIF/25065001B-125

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25065001B-125

# %% [markdown]
# ### NEGATIF/25066602A-153

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25066602A-153

# %% [markdown]
# ###NEGATIF/25090106A-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106A-274

# %% [markdown]
# ###NEGATIF/25090106B-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106B-274

# %% [markdown]
# ###NEGATIF/25077801B-193

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25077801B-193

# %% [markdown]
# ###NEGATIF/25078502A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25078502A-230

# %% [markdown]
# ###NEGATIF/25084301A-229

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25084301A-229

# %% [markdown]
# ###NEGATIF/25089101B-248

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25089101B-248

# %% [markdown]
# Testing epoch=110

# %% [markdown]
# ##Scanty

# %% [markdown]
# ### /Scanty/25001201A-206

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25001201A-206

# %% [markdown]
# ###/Scanty/25014101B-355

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014101B-355

# %% [markdown]
# ###/Scanty/25014801A-367

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014801A-367

# %% [markdown]
# ###/Scanty/25007801B-285_9AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25007801B-285_9AFB

# %% [markdown]
# ### /Scanty/25005101B-229_4AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25005101B-229_4AFB

# %% [markdown]
# ### /Scanty/25018001B-392

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392

# %% [markdown]
# ### /Scanty/25070501A156_21AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501A156_21AFB

# %% [markdown]
# ###/Scanty/25070501B156_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501B156_6AFB

# %% [markdown]
# ###/Scanty/25070801A164_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070801A164_6AFB

# %% [markdown]
# ###/Scanty/25080301A201_12AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25080301A201_12AFB

# %% [markdown]
# ###/Scanty/25094501A303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501A303_6AFB

# %% [markdown]
# ###/Scanty/25094501B303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501B303_6AFB

# %% [markdown]
# ##TB+1

# %% [markdown]
# ### /TB+1/25001001B-204

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25001001B-204

# %% [markdown]
# ### /TB+1/25005001A-220

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25005001A-220

# %% [markdown]
# ### /TB+1/25012501A-342

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25012501A-342

# %% [markdown]
# ###/TB+1/25013501A-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25013501A-344

# %% [markdown]
# ###/TB+1/25018601B-399

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25018601B-399

# %% [markdown]
# ### /TB+1/25023301A-420

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25023301A-420

# %% [markdown]
# ### /TB+1/25051901A-35

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25051901A-35

# %% [markdown]
# ###/TB+1/25070602A-154

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25070602A-154

# %% [markdown]
# ###/TB+1/25080301B-201

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25080301B-201

# %% [markdown]
# ###TB+1/25095601A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601A-313

# %% [markdown]
# ###/TB+1/25095601B-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.16 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601B-313

# %% [markdown]
# #Testing Conf=0.18

# %% [markdown]
# ##Negative

# %% [markdown]
# ### NEGATIF/25012301A-356
# run di awal, jd folder cropnya sudah kehapus

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
#-----------------FOLDER INFORMATION----------------
import os
from keras.preprocessing import image
# getting & setting (chapter-4)
#Import the necessary packages
from __future__ import print_function
import argparse
import cv2
# Import the necessary packages
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from matplotlib import pyplot as plt
from skimage import data, io
from skimage.util import img_as_ubyte
from PIL import Image

def key_func(x):
  return os.path.split(x)[-1]


#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A156" #10imgs
#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A164" #2imgs
dir = "/content/gdrive/MyDrive/37_Y7/yolov7/crop"
initial_count = 0
ARTEFACT=0
BLUEAFB=0
FUNGI=0
REDAFB=0

folderPath = os.path.join(dir)
for path in sorted(os.listdir(dir)):
  img =io.imread(os.path.join(dir, path))
  ori =io.imread(os.path.join(dir, path))
  img= cv2.resize(img, (64, 64))
  img = np.asarray(img)
  #plt.imshow(img),plt.title("Predicted Result"), plt.axis('off')
  img = np.expand_dims(img, axis=0)
  from keras.models import load_model
  saved_model = load_model(r"/content/gdrive/MyDrive/DLStage2_50_10.h5")

  output = saved_model.predict(img)
  #labels = ['ARTEFACT','BLUEAFB','FUNGI','REDAFB']
  if output[0][0] > output[0][1]:
    #print("ARTEFACT")
    ARTEFACT += 1
  elif output[0][1] > output[0][2]:
    BLUEAFB += 1
    #print('BLUEAFB')
  elif output[0][2] > output[0][3]:
    FUNGI += 1
    #print('FUNGI')
  else:
    REDAFB += 1
    #print('BLUEAFB')

  initial_count += 1

print("ARTEFACT:",ARTEFACT, 'image(s)')
print("BLUEAFB :",BLUEAFB, 'image(s)')
print("FUNGI   :",FUNGI, 'image(s)')
print("REDAFB  :",REDAFB, 'image(s)')

#2ndClassification  of OBJECTS
'''
if(ARTEFACT>BLUEAFB) and (ARTEFACT>FUNGI) and (ARTEFACT>REDAFB):
  Object=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTGREEN_EX+ " Good Staining"
elif (BLUEAFB>BLUEAFB) and (BLUEAFB>FUNGI) and (BLUEAFB>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
elif (FUNGI>BLUEAFB) and (FUNGI>Over) and (FUNGI>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
else:
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Over Staining"
'''
'''
  if os.path.isfile(os.path.join(dir, path)):
    plt.figure(num=None, figsize=(16,16))
    plt.subplot(1,2,1), plt.title(os.path.basename(path)), plt.imshow(ori), plt.axis('off')
    #plt.subplot(1,2,2), plt.title("Predicted Result"), plt.imshow(img), plt.axis('off')
    # show the output image
'''
print(" ")
print("---------------------------------")
print('\033[1m' +Fore.BLACK+"Path ID           :",os.path.basename(dir))
print('\033[1m' +Fore.BLACK+"Number of Datasets:",initial_count)

#print('\033[1m' +"Quality of Ziehl-Neelsen Staining:")
#print('\033[1m' +ZNStain)

# %% [markdown]
# ### NEGATIF/25014002B-360

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %% [markdown]
# ### NEGATIF/25022602A-417

# %%
# Run evaluation

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25022602A-417

# %% [markdown]
# ###NEGATIF/25049001 A 20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001A-20

# %% [markdown]
# ###NEGATIF/25049001B-20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001B-20

# %% [markdown]
# ### NEGATIF/25065001B-125

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25065001B-125

# %% [markdown]
# ### NEGATIF/25066602A-153

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25066602A-153

# %% [markdown]
# ###NEGATIF/25090106A-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106A-274

# %% [markdown]
# ###NEGATIF/25090106B-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106B-274

# %% [markdown]
# ###NEGATIF/25077801B-193

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25077801B-193

# %% [markdown]
# ###NEGATIF/25078502A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25078502A-230

# %% [markdown]
# ###NEGATIF/25084301A-229

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25084301A-229

# %% [markdown]
# ###NEGATIF/25089101B-248

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25089101B-248

# %% [markdown]
# Testing epoch=110

# %% [markdown]
# ##Scanty

# %% [markdown]
# ### /Scanty/25001201A-206

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25001201A-206

# %% [markdown]
# ###/Scanty/25014101B-355

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014101B-355

# %% [markdown]
# ###/Scanty/25014801A-367

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014801A-367

# %% [markdown]
# ###/Scanty/25007801B-285_9AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25007801B-285_9AFB

# %% [markdown]
# ### /Scanty/25005101B-229_4AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25005101B-229_4AFB

# %% [markdown]
# ### /Scanty/25018001B-392

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392

# %% [markdown]
# ### /Scanty/25070501A156_21AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501A156_21AFB

# %% [markdown]
# ###/Scanty/25070501B156_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501B156_6AFB

# %% [markdown]
# ###/Scanty/25070801A164_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070801A164_6AFB

# %% [markdown]
# ###/Scanty/25080301A201_12AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25080301A201_12AFB

# %% [markdown]
# ###/Scanty/25094501A303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501A303_6AFB

# %% [markdown]
# ###/Scanty/25094501B303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501B303_6AFB

# %% [markdown]
# ##TB+1

# %% [markdown]
# ### /TB+1/25001001B-204

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25001001B-204

# %% [markdown]
# ### /TB+1/25005001A-220

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25005001A-220

# %% [markdown]
# ### /TB+1/25012501A-342

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25012501A-342

# %% [markdown]
# ###/TB+1/25013501A-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25013501A-344

# %% [markdown]
# ###/TB+1/25018601B-399

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25018601B-399

# %% [markdown]
# ### /TB+1/25023301A-420

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25023301A-420

# %% [markdown]
# ### /TB+1/25051901A-35

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25051901A-35

# %% [markdown]
# ###/TB+1/25070602A-154

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25070602A-154

# %% [markdown]
# ###/TB+1/25080301B-201

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25080301B-201

# %% [markdown]
# ###TB+1/25095601A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601A-313

# %% [markdown]
# ###/TB+1/25095601B-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601B-313

# %% [markdown]
# ##TB2+

# %% [markdown]
# ###TB+2/25001101B-205

# %%
# Run evaluatio
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25001101B-205

# %% [markdown]
# ###/TB+2/25005201A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25005201A-230

# %% [markdown]
# ### /TB+2/25007901A-286

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25007901A-286

# %% [markdown]
# ###/TB+2/25008001A-294

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008001A-294

# %% [markdown]
# ###TB+2/25008101B-295

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008101B-295

# %% [markdown]
# ###/TB+2/25008201A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008201A-313

# %% [markdown]
# ###/TB+2/25009704A-33

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25009704A-33

# %% [markdown]
# ###/TB+2/25009704B-33

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25009704B-33

# %% [markdown]
# ###/TB+2/25012101A-331

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25012101A-331

# %% [markdown]
# ###/TB+2/25013501B-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013501B-344

# %% [markdown]
# ###/TB+2/25013901B-357

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013901B-357

# %% [markdown]
# ###/TB+2/25017301A-371

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25017301A-371

# %% [markdown]
# ###/TB+2/25095201A-310

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201A-310

# %% [markdown]
# ###/TB+2/25095201B-310

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.18  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201B-310

# %% [markdown]
# ##TB3+

# %% [markdown]
# ### TB+3/25000901A1-203

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A1-203

# %% [markdown]
# ### TB+3/25004901A1-219

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25004901A1-219

# %% [markdown]
# ###TB+3/25005401B1-240

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25005401B1-240

# %% [markdown]
# ###TB+3/25006901A1-265

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25006901A1-265

# %% [markdown]
# ###/TB+3/25008101A1-295

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25008101A1-295

# %% [markdown]
# ###/TB+3/25008501A1-299

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25008501A1-299

# %% [markdown]
# ### /TB+3/25009801B1-309

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25009801B1-309

# %% [markdown]
# ###/TB+3/25012101B1-331

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25012101B1-331

# %% [markdown]
# ###TB+3/25021601A1-401

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25021601A1-401

# %% [markdown]
# ###/TB+3/25023901A-423

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25023901A-423

# %% [markdown]
# ###/TB+3/25024001A-425

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25024001A-425

# %% [markdown]
# ###/TB+3/BlindTB3/25080801B-209

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25080801B-209

# %% [markdown]
# ###/TB+3/BlindTB3/25066601B-131

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25066601B-131

# %% [markdown]
# ###/TB+3/BlindTB3/25050901B-74

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25050901B-74

# %% [markdown]
# ###/TB+3/BlindTB3/25050901A-74

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25050901A-74

# %% [markdown]
# #Testing Conf=0.17

# %% [markdown]
# ##SampleData

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/sampledata/oldA230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/OLD_25008201A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/OLD_25095201A-310

# %% [markdown]
# Agustus

# %% [markdown]
# ##Negative

# %% [markdown]
# ### NEGATIF/25012301A-356

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/NegNewAdd/neg5_9_252img

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/NegNewAdd/oriB303

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
import glob
removingfiles = glob.glob('/content/gdrive/MyDrive/37_Y7/yolov7/crop*.jpg')

for i in removingfiles:
  os.remove(i)

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.15 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25012301A-356

# %%
#-----------------FOLDER INFORMATION----------------
import os
from keras.preprocessing import image
# getting & setting (chapter-4)
#Import the necessary packages
from __future__ import print_function
import argparse
import cv2
# Import the necessary packages
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from matplotlib import pyplot as plt
from skimage import data, io
from skimage.util import img_as_ubyte
from PIL import Image

def key_func(x):
  return os.path.split(x)[-1]


#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A156" #10imgs
#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A164" #2imgs
dir = "/content/gdrive/MyDrive/37_Y7/yolov7/crop"
initial_count = 0
ARTEFACT=0
BLUEAFB=0
FUNGI=0
REDAFB=0

folderPath = os.path.join(dir)
for path in sorted(os.listdir(dir)):
  img =io.imread(os.path.join(dir, path))
  ori =io.imread(os.path.join(dir, path))
  img= cv2.resize(img, (64, 64))
  img = np.asarray(img)
  #plt.imshow(img),plt.title("Predicted Result"), plt.axis('off')
  img = np.expand_dims(img, axis=0)
  from keras.models import load_model
  saved_model = load_model(r"/content/gdrive/MyDrive/DLStage2_50_10.h5")

  output = saved_model.predict(img)
  #labels = ['ARTEFACT','BLUEAFB','FUNGI','REDAFB']
  if output[0][0] > output[0][1]:
    #print("ARTEFACT")
    ARTEFACT += 1
  elif output[0][1] > output[0][2]:
    BLUEAFB += 1
    #print('BLUEAFB')
  elif output[0][2] > output[0][3]:
    FUNGI += 1
    #print('FUNGI')
  else:
    REDAFB += 1
    #print('BLUEAFB')

  initial_count += 1

print("ARTEFACT:",ARTEFACT, 'image(s)')
print("BLUEAFB :",BLUEAFB, 'image(s)')
print("FUNGI   :",FUNGI, 'image(s)')
print("REDAFB  :",REDAFB, 'image(s)')

#2ndClassification  of OBJECTS
'''
if(ARTEFACT>BLUEAFB) and (ARTEFACT>FUNGI) and (ARTEFACT>REDAFB):
  Object=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTGREEN_EX+ " Good Staining"
elif (BLUEAFB>BLUEAFB) and (BLUEAFB>FUNGI) and (BLUEAFB>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
elif (FUNGI>BLUEAFB) and (FUNGI>Over) and (FUNGI>REDAFB):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
else:
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Over Staining"
'''
'''
  if os.path.isfile(os.path.join(dir, path)):
    plt.figure(num=None, figsize=(16,16))
    plt.subplot(1,2,1), plt.title(os.path.basename(path)), plt.imshow(ori), plt.axis('off')
    #plt.subplot(1,2,2), plt.title("Predicted Result"), plt.imshow(img), plt.axis('off')
    # show the output image
'''
print(" ")
print("---------------------------------")
print('\033[1m' +Fore.BLACK+"Path ID           :",os.path.basename(dir))
print('\033[1m' +Fore.BLACK+"Number of Datasets:",initial_count)

#print('\033[1m' +"Quality of Ziehl-Neelsen Staining:")
#print('\033[1m' +ZNStain)

# %% [markdown]
# ### NEGATIF/25014002B-360

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.2 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25014002B-360

# %% [markdown]
# ### NEGATIF/25022602A-417

# %%
# Run evaluation

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25022602A-417

# %% [markdown]
# Positive di old A417

# %%
# Run evaluation

# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25022602A-417

# %% [markdown]
# ###NEGATIF/25090106A-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106A-274

# %% [markdown]
# ###NEGATIF/25089101B-248

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25089101B-248

# %% [markdown]
# Testing epoch=110

# %% [markdown]
# ###NEGATIF/25084301A-229

# %%
# Run evaluation-----------------------------------37-800epoch
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-37-800epoch-noresize/weights/best.pt --conf 0.43 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25084301A-229

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25084301A-229

# %% [markdown]
# ###NEGATIF/25078502A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25078502A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25078502A-230/Neg2306Sept

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25078502A-230

# %% [markdown]
# ###NEGATIF/25077801B-193

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25077801B-193

# %% [markdown]
# ### NEGATIF/25066602A-153

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25066602A-153

# %% [markdown]
# ### NEGATIF/25065001B-125

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25065001B-125

# %% [markdown]
# ###NEGATIF/25049001B-20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001B-20

# %% [markdown]
# ###NEGATIF/25049001 A 20

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/OLD_25049001B-20positive

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25049001A-20

# %% [markdown]
# ###NEGATIF/25090106B-274

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/NEGATIF/25090106B-274

# %% [markdown]
# ##Scanty

# %% [markdown]
# ###/Scanty/25014101B-355

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014101B-355

# %% [markdown]
# ### /Scanty/25018001B-392

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392/12April

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392/1juni

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392/22Maret

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392/7Maret

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392/9April

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25018001B-392

# %% [markdown]
# ###/Scanty/25014801A-367

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014801A-367

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/old_25014801A-367_21Maret

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25014801A-367

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/old_25014801A-367

# %% [markdown]
# ### /Scanty/25001201A-206

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25001201A-206

# %% [markdown]
# ### /Scanty/25005101B-229_4AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25005101B-229_4AFB

# %% [markdown]
# ###/Scanty/25007801B-285_9AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25007801B-285_9AFB

# %% [markdown]
# ### /Scanty/25070501A156_21AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501A156_21AFB

# %% [markdown]
# ###/Scanty/25070501B156_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/Old_OriNeg_B156_28Agustus

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501B156_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070501B156_6AFB

# %% [markdown]
# ###/Scanty/25070801A164_6AFB

# %%
# Run evaluation-----------------------------------37-800epoch
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-37-800epoch-noresize/weights/best.pt --conf 0.43 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070801A164

# %%
# Run evaluation-----------------------------------37-800epoch
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-37-800epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070801A164_6AFB

# %%
# Run evaluation-----------------------37-110epoch
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25070801A164_6AFB

# %% [markdown]
# ###/Scanty/25080301A201_12AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25080301A201_12AFB

# %% [markdown]
# ###/Scanty/25094501A303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501A303_6AFB

# %% [markdown]
# ###/Scanty/25094501B303_6AFB

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/Scanty/25094501B303_6AFB

# %% [markdown]
# ##TB+1

# %% [markdown]
# ### /TB+1/25001001B-204

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25001001B-204

# %% [markdown]
# ### /TB+1/25005001A-220

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25005001A-220

# %% [markdown]
# ### /TB+1/25012501A-342

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25012501A-342

# %% [markdown]
# ###/TB+1/25013501A-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25013501A-344

# %% [markdown]
# ###/TB+1/25013501B-344

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25013501B-344

# %% [markdown]
# ###/TB+1/25018601B-399

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25018601B-399

# %% [markdown]
# ### /TB+1/25023301A-420

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25023301A-420

# %% [markdown]
# ### /TB+1/25051901A-35

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25051901A-35

# %% [markdown]
# ###/TB+1/25070602A-154

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25070602A-154

# %% [markdown]
# ###/TB+1/25080301B-201

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25080301B-201

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25080301B-201

# %% [markdown]
# ###TB+1/25095601A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601A-313

# %% [markdown]
# ###/TB+1/25095601B-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+1/25095601B-313

# %% [markdown]
# ##TB2+

# %% [markdown]
# ###TB+2/25001101B-205

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25001101B-205

# %% [markdown]
# ###/TB+2/25005201A-230

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25005201A-230

# %% [markdown]
# ### /TB+2/25007901A-286

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25007901A-286

# %% [markdown]
# ###/TB+2/25008001A-294

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008001A-294

# %% [markdown]
# ###TB+2/25008101B-295

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/sampledata/TB1+_25023201A415

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008101B-295

# %% [markdown]
# ###/TB+2/25008201A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008201A-313

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25008201A-313

# %% [markdown]
# ###/TB+2/25009704A-33

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25009704A-33

# %% [markdown]
# ###/TB+2/25009704B-33

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25009704B-33

# %% [markdown]
# ###/TB+2/25012101A-331

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25012101A-331

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25012101A-331

# %% [markdown]
# ###/TB+2/25013901B-357

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013901B-357

# %% [markdown]
# ###TB+2/25013901A-357

# %%
# Run evaluation-----------------------------------37-800epoch
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-37-800epoch-noresize/weights/best.pt --conf 0.43 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013901A-357

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013901A-357

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25013901A-357

# %% [markdown]
# ###/TB+2/25017301A-371

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25017301A-371

# %% [markdown]
# ###/TB+2/25095201A-310

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201A-310

# %% [markdown]
# ###/TB+2/25095201B-310

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17  --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+2/25095201B-310

# %% [markdown]
# ##TB3+

# %% [markdown]
# ### TB+3/25000901A1-203

# %%
# Run evaluation-----------------------------------37-800epoch
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-37-800epoch-noresize/weights/best.pt --conf 0.43 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A1-203

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25000901A1-203

# %% [markdown]
# ### TB+3/25004901A1-219

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25004901A1-219

# %% [markdown]
# ###TB+3/25005401B1-240

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25005401B1-240

# %% [markdown]
# ###TB+3/25006901A1-265

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25006901A1-265

# %% [markdown]
# ###/TB+3/25008101A1-295

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25008101A1-295

# %% [markdown]
# ###/TB+3/25008501A1-299

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25008501A1-299

# %% [markdown]
# ### /TB+3/25009801B1-309

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25009801B1-309

# %% [markdown]
# ###/TB+3/25012101B1-331

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25012101B1-331

# %% [markdown]
# ###TB+3/25021601A1-401

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25021601A1-401

# %% [markdown]
# ###/TB+3/25023901A-423

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25023901A-423

# %% [markdown]
# ###/TB+3/25024001A-425

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/25024001A-425

# %% [markdown]
# ###/TB+3/BlindTB3/25080801B-209

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25080801B-209

# %% [markdown]
# ###/TB+3/BlindTB3/25066601B-131

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25066601B-131

# %% [markdown]
# ###/TB+3/BlindTB3/25050901B-74

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.1 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25050901B-74

# %% [markdown]
# ###/TB+3/BlindTB3/25050901A-74

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/25050901A-74

# %% [markdown]
# ###OLD_25050901B-74_1

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/OLD_25050901B-74_1

# %% [markdown]
# ###OLD_25050901B-74_2

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/OLD_25050901B-74

# %% [markdown]
# ###OLD_25050901A-74_1

# %%
# Run evaluation
# !python detect.py --weights /content/gdrive/MyDrive/37_Y7/yolov7/runs/train/Yolov7w6-371-110epoch-noresize/weights/best.pt --conf 0.17 --source /content/gdrive/MyDrive/MIDBTBI/POSITIF/TB+3/BlindTB3/OLD_25050901A-74_1

# %% [markdown]
# #ZN Filtering

# %%
#-----------------FOLDER INFORMATION----------------
import os
from keras.preprocessing import image
# getting & setting (chapter-4)
#Import the necessary packages
from __future__ import print_function
import argparse
import cv2
# Import the necessary packages
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from matplotlib import pyplot as plt
from skimage import data, io
from skimage.util import img_as_ubyte
from PIL import Image

def key_func(x):
  return os.path.split(x)[-1]


#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A156" #10imgs
#dir ="/content/drive/MyDrive/MIDBTBI/Trial2/A164" #2imgs
dir = "/content/gdrive/MyDrive/MIDBTBI/DatasetFiltered/B392"
initial_count = 0
Good=0
Less=0
Over=0

folderPath = os.path.join(dir)
for path in sorted(os.listdir(dir)):
  img =io.imread(os.path.join(dir, path))
  ori =io.imread(os.path.join(dir, path))
  img= cv2.resize(img, (64, 64))
  img = np.asarray(img)
  #plt.imshow(img),plt.title("Predicted Result"), plt.axis('off')
  img = np.expand_dims(img, axis=0)
  from keras.models import load_model
  saved_model = load_model(r"/content/gdrive/MyDrive/DLStage2_50_10.h5")

  output = saved_model.predict(img)

  if output[0][0] > output[0][1]:
    print(os.path.basename(path),": Good Staining")
    Good += 1
  elif output[0][1] > output[0][2]:
    Less += 1
    print(os.path.basename(path),": Less Staining")
    #print('LessStaining')
  else:
    Over += 1
    print(os.path.basename(path),": Over Staining")
    #print('OverStaining')

  initial_count += 1

print("Good Staining:",Good, 'image(s)')
print("Less Staining:",Less, 'image(s)')
print("Over Staining:",Over, 'image(s)')
#Classification Quality of ZN Staining

if(Good>Less) and (Good>Over):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTGREEN_EX+ " Good Staining"
elif (Less>Good) and (Less>Over):
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Less Staining"
else:
  ZNStain=Fore.BLACK+"ZN Quality        :"+Fore.LIGHTRED_EX+ " Over Staining"

'''
  if os.path.isfile(os.path.join(dir, path)):
    plt.figure(num=None, figsize=(16,16))
    plt.subplot(1,2,1), plt.title(os.path.basename(path)), plt.imshow(ori), plt.axis('off')
    #plt.subplot(1,2,2), plt.title("Predicted Result"), plt.imshow(img), plt.axis('off')
    # show the output image
'''
print(" ")
print("---------------------------------")
print('\033[1m' +Fore.BLACK+"Path ID           :",os.path.basename(dir))
print('\033[1m' +Fore.BLACK+"Number of Datasets:",initial_count)

#print('\033[1m' +"Quality of Ziehl-Neelsen Staining:")
print('\033[1m' +ZNStain)

# %% [markdown]
# # 5.1.2 Display Inference on Folder of Test Images
#
# **Note** From the above output display copy the full path of folder where test images are stored

# %%
import os
from skimage import data, io
import matplotlib.pyplot as plt
dir='/content/gdrive/MyDrive/yolov7/runs/detect/exp3'
for path in os.listdir(dir):
        image =io.imread(os.path.join(dir, path))
        plt.figure(figsize=(16, 10))
        plt.subplot(1, 2, 1), plt.title(os.path.basename(path)), plt.imshow(image), plt.axis('off')

# %%
from skimage import data, io
import matplotlib.pyplot as plt
dir='/content/gdrive/MyDrive/yolov7/runs/detect/exp3'
for path in os.listdir(dir):
        image =io.imread(os.path.join(dir, path))
        plt.figure(figsize=(16, 10))
        plt.subplot(1, 2, 1), plt.title(os.path.basename(path)), plt.imshow(image), plt.axis('off')

# %%
#display inference on ALL test images SCA

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.JPG'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

i = 0
limit = 10000 # max images to print
for imageName in glob.glob('/content/gdrive/MyDrive/yolov7/runs/detect/exp2/*.jpg'):
    #Assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

display(Image("/content/gdrive/MyDrive/yolov7/runs/detect/exp3/52_jpg.rf.c3931652d0d6e62034543e92ec110c0b.jpg", width=400, height=400))
